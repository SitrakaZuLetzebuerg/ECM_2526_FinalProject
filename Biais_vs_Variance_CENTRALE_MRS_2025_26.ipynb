# %% [markdown]
# <a href="https://colab.research.google.com/github/SitrakaZuLetzebuerg/ECM_2526_FinalProject/blob/main/Biais_vs_Variance_CENTRALE_MRS_2025_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quel package utilisé pour le biais vs la variance ?
# Usuellement on a pandas, numpy matplotlib seaborn et surtout ...
# scikitlearn
# !pip install scikit-learn pandas numpy matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Machine Learning functions imported in this notebook from scikit-learn include:")
print("- Data splitting: train_test_split")
print("- Model evaluation: learning_curve")
print("- Preprocessing: StandardScaler")
print("- Metrics: mean_squared_error, r2_score")
print("- Models: LinearRegression")

# %%
# sachez que certains packages ont des DATASETS de sauvegardés !
# Sci kit learn propose celui des housing californiens.
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
